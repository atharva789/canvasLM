# %%
# Out:
# 2025-01-26 06:19:10,674 [MainThread  ] [INFO ]  Retrieving https://canvas.case.edu/files/7949353/download?download_frd=1&verifier=sMxr1ilMrtUYjEbTaBRTQl2LTeLVAp7zp7h0OL19 to C:\Users\ekkoi\AppData\Local\Temp/files-7949353-download.
# Recitation 9-6-24
#
# CSDS 310: Algorithms
#
# September 2024
#
# PLEASE NOTE:
#
# • YOU DO NOT NEED TO PRESENT THE INTUITION SECTION. IT IS PURELY
# THERE FOR US TO PROVIDE QUICK NOTES REGARDING HOW WE SOLVED
# THESE PROBLEMS
#
# • We are using 1-based array indices
#
# 1 Problem 1: Valid Palindrome
#
# 1.1 Problem Statement
#
# Given a sequence of lowercase characters, return true if the sequence is a palindrome, otherwise return false.
# A palindrome is defined as a sequence, S =< s1, . . . , sn >, that reads the same forward and backward, i.e.
# si = sn−i+1 for 1 ≤ i ≤ ⌊n/2⌋ where n is the length of the the sequence. Here are some examples
#
# • tacacat
#
# • wasitacaroracatisaw
#
# Assume the strings do not contain any white spaces.
#
# ...
